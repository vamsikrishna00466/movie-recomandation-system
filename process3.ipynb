# %%
pip install lxml
# Out:
# Collecting lxmlNote: you may need to restart the kernel to use updated packages.
#   Downloading lxml-4.6.2-cp37-cp37m-win_amd64.whl (3.5 MB)
# Installing collected packages: lxml
# Successfully installed lxml-4.6.2

# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 262  DECEMBER         25             Holmes & Watson
# 263  DECEMBER         25                        Vice
# 264  DECEMBER         25         On the Basis of Sex
# 265  DECEMBER         25                   Destroyer
# 266  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 262       Columbia Pictures / Gary Sanchez Productions
# 263          Annapurna Pictures / Plan B Entertainment
# 264                                     Focus Features
# 265                                 Annapurna Pictures
# 266                                            Netflix
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Lauren Wolkstein (director); Christopher Radcl...    [3]
# 2    Simon West (director); Duncan Falconer, Warren...    [4]
# 3    Warwick Thornton (director); David Tranter, St...    [5]
# 4    Jaume Collet-Serra (director); Byron Willinger...    [6]
# ..                                                 ...    ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...  [162]
# 263  Adam McKay (director/screenplay); Christian Ba...  [136]
# 264  Mimi Leder (director); Daniel Stiepleman (scre...  [223]
# 265  Karyn Kusama (director); Phil Hay, Matt Manfre...  [255]
# 266  David Slade (director); Charlie Brooker (scree...  [256]
#
# [267 rows x 6 columns]

# %%
pip install tmdbv3api
# Out:
# Collecting tmdbv3apiNote: you may need to restart the kernel to use updated packages.
#   Downloading tmdbv3api-1.7.1-py2.py3-none-any.whl (15 kB)
# Collecting requests
#   Downloading requests-2.25.0-py2.py3-none-any.whl (61 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ssc\anaconda3\envs\movies1\lib\site-packages (from requests->tmdbv3api) (2020.12.5)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.2-py2.py3-none-any.whl (136 kB)
#
# Installing collected packages: urllib3, idna, chardet, requests, tmdbv3api
# Successfully installed chardet-3.0.4 idna-2.10 requests-2.25.0 tmdbv3api-1.7.1 urllib3-1.26.2

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'eee910e8cb81b6e613b9de55fd9c03c3'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\http\client.py in getresponse(self)
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\http\client.py in begin(self)
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\http\client.py in _read_status(self)
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ConnectionAbortedError: [WinError 10053] An established connection was aborted by the software in your host machine
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     755             retries = retries.increment(
# --> 756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757             )
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     530             if read is False or not self._is_method_retryable(method):
# --> 531                 raise six.reraise(type(error), error, _stacktrace)
#     532             elif read is not None:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\http\client.py in getresponse(self)
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\http\client.py in begin(self)
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\http\client.py in _read_status(self)
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-9-060ce728dee3> in <module>
# ----> 1 df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3981         dtype: object
#    3982         """
# -> 3983         new_values = super()._map_values(arg, na_action=na_action)
#    3984         return self._constructor(new_values, index=self.index).__finalize__(
#    3985             self, method="map"
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1158
#    1159         # mapper is a function
# -> 1160         new_values = map_f(values, mapper)
#    1161
#    1162         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-9-060ce728dee3> in <lambda>(x)
# ----> 1 df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
#
# <ipython-input-8-3c8c2f8da7a2> in get_genre(x)
#       3 def get_genre(x):
#       4     genres = []
# ----> 5     result = tmdb_movie.search(x)
#       6     movie_id = result[0].id
#       7     response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\tmdbv3api\objs\movie.py in search(self, term, page)
#     157             self._call(
#     158                 self._urls["search_movie"],
# --> 159                 "query=" + quote(term) + "&page=" + str(page),
#     160             )
#     161         )
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\tmdbv3api\tmdb.py in _call(self, action, append_to_response, call_cached, method, data)
#     130
#     131         if self.cache and self.obj_cached and call_cached and method is not "POST":
# --> 132             req = self.cached_request(method, url, data)
#     133         else:
#     134             req = requests.request(method, url, data=data)
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\tmdbv3api\tmdb.py in cached_request(method, url, data)
#     110     @lru_cache(maxsize=REQUEST_CACHE_MAXSIZE)
#     111     def cached_request(method, url, data):
# --> 112         return requests.request(method, url, data=data)
#     113
#     114     def cache_clear(self):
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 262  DECEMBER         25             Holmes & Watson
# 263  DECEMBER         25                        Vice
# 264  DECEMBER         25         On the Basis of Sex
# 265  DECEMBER         25                   Destroyer
# 266  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 262       Columbia Pictures / Gary Sanchez Productions
# 263          Annapurna Pictures / Plan B Entertainment
# 264                                     Focus Features
# 265                                 Annapurna Pictures
# 266                                            Netflix
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Lauren Wolkstein (director); Christopher Radcl...    [3]
# 2    Simon West (director); Duncan Falconer, Warren...    [4]
# 3    Warwick Thornton (director); David Tranter, St...    [5]
# 4    Jaume Collet-Serra (director); Byron Willinger...    [6]
# ..                                                 ...    ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...  [162]
# 263  Adam McKay (director/screenplay); Christian Ba...  [136]
# 264  Mimi Leder (director); Daniel Stiepleman (scre...  [223]
# 265  Karyn Kusama (director); Phil Hay, Matt Manfre...  [255]
# 266  David Slade (director); Charlie Brooker (scree...  [256]
#
#                                               genres
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                                    Action Thriller
# ..                                               ...
# 262                   Mystery Adventure Comedy Crime
# 263        Thriller Science Fiction Action Adventure
# 264                                    Drama History
# 265                      Thriller Crime Drama Action
# 266  Science Fiction Mystery Drama Thriller TV Movie
#
# [267 rows x 7 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 262             Holmes & Watson
# 263                        Vice
# 264         On the Basis of Sex
# 265                   Destroyer
# 266  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...
# 263  Adam McKay (director/screenplay); Christian Ba...
# 264  Mimi Leder (director); Daniel Stiepleman (scre...
# 265  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 266  David Slade (director); Charlie Brooker (scree...
#
#                                               genres
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                              Drama History Western
# 4                                    Action Thriller
# ..                                               ...
# 262                   Mystery Adventure Comedy Crime
# 263        Thriller Science Fiction Action Adventure
# 264                                    Drama History
# 265                      Thriller Crime Drama Action
# 266  Science Fiction Mystery Drama Thriller TV Movie
#
# [267 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 262             Holmes & Watson
# 263                        Vice
# 264         On the Basis of Sex
# 265                   Destroyer
# 266  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 262  Etan Cohen (director/screenplay); Will Ferrell...
# 263  Adam McKay (director/screenplay); Christian Ba...
# 264  Mimi Leder (director); Daniel Stiepleman (scre...
# 265  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 266  David Slade (director); Charlie Brooker (scree...
#
#                                               genres       director_name  \
# 0                            Horror Mystery Thriller        Adam Robitel
# 1                                     Thriller Drama    Lauren Wolkstein
# 2                                    Action Thriller          Simon West
# 3                              Drama History Western    Warwick Thornton
# 4                                    Action Thriller  Jaume Collet-Serra
# ..                                               ...                 ...
# 262                   Mystery Adventure Comedy Crime          Etan Cohen
# 263        Thriller Science Fiction Action Adventure          Adam McKay
# 264                                    Drama History          Mimi Leder
# 265                      Thriller Crime Drama Action        Karyn Kusama
# 266  Science Fiction Mystery Drama Thriller TV Movie         David Slade
#
#         actor_1_name            actor_2_name    actor_3_name
# 0          Lin Shaye           Angus Sampson  Leigh Whannell
# 1      Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2     Dominic Cooper          Austin Stowell      Gemma Chan
# 3        Bryan Brown               Sam Neill             NaN
# 4        Liam Neeson            Vera Farmiga  Patrick Wilson
# ..               ...                     ...             ...
# 262     Will Ferrell          John C. Reilly    Rebecca Hall
# 263   Christian Bale               Amy Adams    Steve Carell
# 264   Felicity Jones            Armie Hammer  Justin Theroux
# 265    Nicole Kidman          Sebastian Stan    Toby Kebbell
# 266  Fionn Whitehead            Will Poulter   Asim Chaudhry
#
# [267 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 262          Etan Cohen     Will Ferrell          John C. Reilly
# 263          Adam McKay   Christian Bale               Amy Adams
# 264          Mimi Leder   Felicity Jones            Armie Hammer
# 265        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 266         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3               NaN                            Drama History Western
# 4    Patrick Wilson                                  Action Thriller
# ..              ...                                              ...
# 262    Rebecca Hall                   Mystery Adventure Comedy Crime
# 263    Steve Carell        Thriller Science Fiction Action Adventure
# 264  Justin Theroux                                    Drama History
# 265    Toby Kebbell                      Thriller Crime Drama Action
# 266   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 262             Holmes & Watson
# 263                        Vice
# 264         On the Basis of Sex
# 265                   Destroyer
# 266  Black Mirror: Bandersnatch
#
# [267 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 262          Etan Cohen     Will Ferrell          John C. Reilly
# 263          Adam McKay   Christian Bale               Amy Adams
# 264          Mimi Leder   Felicity Jones            Armie Hammer
# 265        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 266         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name                                           genres  \
# 0    Leigh Whannell                          Horror Mystery Thriller
# 1     Emily Althaus                                   Thriller Drama
# 2        Gemma Chan                                  Action Thriller
# 3           unknown                            Drama History Western
# 4    Patrick Wilson                                  Action Thriller
# ..              ...                                              ...
# 262    Rebecca Hall                   Mystery Adventure Comedy Crime
# 263    Steve Carell        Thriller Science Fiction Action Adventure
# 264  Justin Theroux                                    Drama History
# 265    Toby Kebbell                      Thriller Crime Drama Action
# 266   Asim Chaudhry  Science Fiction Mystery Drama Thriller TV Movie
#
#                     movie_title  \
# 0       insidious: the last key
# 1              the strange ones
# 2                      stratton
# 3                 sweet country
# 4                  the commuter
# ..                          ...
# 262             holmes & watson
# 263                        vice
# 264         on the basis of sex
# 265                   destroyer
# 266  black mirror: bandersnatch
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 262  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 263  Christian Bale Amy Adams Steve Carell Adam McK...
# 264  Felicity Jones Armie Hammer Justin Theroux Mim...
# 265  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 266  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [267 rows x 7 columns]

# %% [markdown]
# Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1             Title  \
# 0     JANUARY          4       Escape Room
# 1     JANUARY          4        Rust Creek
# 2     JANUARY          4  American Hangman
# 3     JANUARY         11  A Dog's Way Home
# 4     JANUARY         11        The Upside
# ..        ...        ...               ...
# 238  DECEMBER         25      Little Women
# 239  DECEMBER         25              1917
# 240  DECEMBER         25        Just Mercy
# 241  DECEMBER         27          Clemency
# 242  DECEMBER         27        Apparition
#
#                                     Production company  \
# 0                                    Columbia Pictures
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 238            Columbia Pictures / Regency Enterprises
# 239  Universal Pictures / DreamWorks Pictures / Ent...
# 240          Warner Bros. Pictures / Participant Media
# 241                                               Neon
# 242                                  Vertical Pictures
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 238  Greta Gerwig (director/screenplay); Saoirse Ro...  [223]
# 239  Sam Mendes (director/screenplay); Krysty Wilso...  [224]
# 240  Destin Daniel Cretton (director/screenplay), A...  [225]
# 241  Chinonye Chukwu (director/screenplay); Alfre W...  [226]
# 242  Waymon Boone (director/screenplay); Mena Suvar...  [227]
#
# [243 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\http\client.py in getresponse(self)
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\http\client.py in begin(self)
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\http\client.py in _read_status(self)
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     755             retries = retries.increment(
# --> 756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757             )
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     530             if read is False or not self._is_method_retryable(method):
# --> 531                 raise six.reraise(type(error), error, _stacktrace)
#     532             elif read is not None:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\http\client.py in getresponse(self)
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\http\client.py in begin(self)
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\http\client.py in _read_status(self)
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#
# c:\users\ssc\anaconda3\envs\movies1\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-33-060ce728dee3> in <module>
# ----> 1 df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3981         dtype: object
#    3982         """
# -> 3983         new_values = super()._map_values(arg, na_action=na_action)
#    3984         return self._constructor(new_values, index=self.index).__finalize__(
#    3985             self, method="map"
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1158
#    1159         # mapper is a function
# -> 1160         new_values = map_f(values, mapper)
#    1161
#    1162         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-33-060ce728dee3> in <lambda>(x)
# ----> 1 df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
#
# <ipython-input-8-3c8c2f8da7a2> in get_genre(x)
#       3 def get_genre(x):
#       4     genres = []
# ----> 5     result = tmdb_movie.search(x)
#       6     movie_id = result[0].id
#       7     response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\tmdbv3api\objs\movie.py in search(self, term, page)
#     157             self._call(
#     158                 self._urls["search_movie"],
# --> 159                 "query=" + quote(term) + "&page=" + str(page),
#     160             )
#     161         )
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\tmdbv3api\tmdb.py in _call(self, action, append_to_response, call_cached, method, data)
#     130
#     131         if self.cache and self.obj_cached and call_cached and method is not "POST":
# --> 132             req = self.cached_request(method, url, data)
#     133         else:
#     134             req = requests.request(method, url, data=data)
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\tmdbv3api\tmdb.py in cached_request(method, url, data)
#     110     @lru_cache(maxsize=REQUEST_CACHE_MAXSIZE)
#     111     def cached_request(method, url, data):
# --> 112         return requests.request(method, url, data=data)
#     113
#     114     def cache_clear(self):
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                 Title                                      Cast and crew  \
# 0         Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1          Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2    American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3    A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4          The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                ...                                                ...
# 238      Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 239              1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 240        Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 241          Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
# 242        Apparition  Waymon Boone (director/screenplay); Mena Suvar...
#
#                                        genres
# 0    Thriller Action Mystery Adventure Horror
# 1                              Thriller Drama
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 238                             Drama Romance
# 239                          War Drama Action
# 240                                     Drama
# 241                                     Drama
# 242                           Horror Thriller
#
# [243 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#              director_name         actor_1_name          actor_2_name  \
# 0             Adam Robitel       Taylor Russell          Logan Miller
# 1              Jen McGowan    Hermione Corfield           Jay Paulson
# 2        Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3     Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4              Neil Burger       Bryan Cranston            Kevin Hart
# ..                     ...                  ...                   ...
# 238           Greta Gerwig        Saoirse Ronan           Emma Watson
# 239             Sam Mendes        George MacKay  Dean-Charles Chapman
# 240  Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 241        Chinonye Chukwu        Alfre Woodard        Wendell Pierce
# 242           Waymon Boone          Mena Suvari          Kevin Pollak
#
#          actor_3_name                                    genres  \
# 0    Deborah Ann Woll  Thriller Action Mystery Adventure Horror
# 1        Sean O'Bryan                            Thriller Drama
# 2       Oliver Dennis                                  Thriller
# 3     Alexandra Shipp                    Drama Adventure Family
# 4       Nicole Kidman                              Comedy Drama
# ..                ...                                       ...
# 238     Florence Pugh                             Drama Romance
# 239       Mark Strong                          War Drama Action
# 240       Brie Larson                                     Drama
# 241       Aldis Hodge                                     Drama
# 242           unknown                           Horror Thriller
#
#           movie_title                                               comb
# 0         escape room  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1          rust creek  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2    american hangman  Donald Sutherland Vincent Kartheiser Oliver De...
# 3    a dog's way home  Bryce Dallas Howard Edward James Olmos Alexand...
# 4          the upside  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                ...                                                ...
# 238      little women  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 239              1917  George MacKay Dean-Charles Chapman Mark Strong...
# 240        just mercy  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 241          clemency  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 242        apparition  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [243 rows x 7 columns]

# %%
my_df = new_df18.append(new_df19,ignore_index=True)

# %%
my_df
# Out:
#              director_name       actor_1_name            actor_2_name  \
# 0             Adam Robitel          Lin Shaye           Angus Sampson
# 1         Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2               Simon West     Dominic Cooper          Austin Stowell
# 3         Warwick Thornton        Bryan Brown               Sam Neill
# 4       Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                     ...                ...                     ...
# 505           Greta Gerwig      Saoirse Ronan             Emma Watson
# 506             Sam Mendes      George MacKay    Dean-Charles Chapman
# 507  Destin Daniel Cretton  Michael B. Jordan              Jamie Foxx
# 508        Chinonye Chukwu      Alfre Woodard          Wendell Pierce
# 509           Waymon Boone        Mena Suvari            Kevin Pollak
#
#        actor_3_name                   genres              movie_title  \
# 0    Leigh Whannell  Horror Mystery Thriller  insidious: the last key
# 1     Emily Althaus           Thriller Drama         the strange ones
# 2        Gemma Chan          Action Thriller                 stratton
# 3           unknown    Drama History Western            sweet country
# 4    Patrick Wilson          Action Thriller             the commuter
# ..              ...                      ...                      ...
# 505   Florence Pugh            Drama Romance             little women
# 506     Mark Strong         War Drama Action                     1917
# 507     Brie Larson                    Drama               just mercy
# 508     Aldis Hodge                    Drama                 clemency
# 509         unknown          Horror Thriller               apparition
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 505  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 506  George MacKay Dean-Charles Chapman Mark Strong...
# 507  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 508  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 509  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [510 rows x 7 columns]

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5359       Keith Stanfield                   Romance Comedy
# 5360     Jean Louisa Kelly                          Romance
# 5361        Tiitus Rantala                   Romance Comedy
# 5362           Gina Holden       Crime Comedy Action Family
# 5363        Akshaye Khanna             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5359  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#               director_name       actor_1_name          actor_2_name  \
# 0             James Cameron        CCH Pounder      Joel David Moore
# 1            Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                Sam Mendes    Christoph Waltz          Rory Kinnear
# 3         Christopher Nolan          Tom Hardy        Christian Bale
# 4               Doug Walker        Doug Walker            Rob Walker
# ...                     ...                ...                   ...
# 5869           Greta Gerwig      Saoirse Ronan           Emma Watson
# 5870             Sam Mendes      George MacKay  Dean-Charles Chapman
# 5871  Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5872        Chinonye Chukwu      Alfre Woodard        Wendell Pierce
# 5873           Waymon Boone        Mena Suvari          Kevin Pollak
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5869         Florence Pugh                    Drama Romance
# 5870           Mark Strong                 War Drama Action
# 5871           Brie Larson                            Drama
# 5872           Aldis Hodge                            Drama
# 5873               unknown                  Horror Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5869                                       little women
# 5870                                               1917
# 5871                                         just mercy
# 5872                                           clemency
# 5873                                         apparition
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5869  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5870  George MacKay Dean-Charles Chapman Mark Strong...
# 5871  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5872  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 5873  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [5874 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           5
# movie_title      0
# comb             5
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('final_data.csv',index=False)
