# %%
pip install bs4
# Out:
# Collecting bs4Note: you may need to restart the kernel to use updated packages.
#   Using cached bs4-0.0.1-cp37-none-any.whl
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.1-py3-none-any.whl (32 kB)
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.9.3 bs4-0.0.1 soupsieve-2.1

# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
#Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                  Title  \
# 0     JANUARY          3             The Grudge
# 1     JANUARY         10             Underwater
# 2     JANUARY         10            Like a Boss
# 3     JANUARY         10          Three Christs
# 4     JANUARY         10      Inherit the Viper
# ..        ...        ...                    ...
# 263  DECEMBER         25       We Can Be Heroes
# 264  DECEMBER         25      News of the World
# 265  DECEMBER         25     One Night in Miami
# 266  DECEMBER         25  Promising Young Woman
# 267  DECEMBER         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                                   Paramount Pictures
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 263                     Netflix / Troublemaker Studios
# 264            Universal Pictures / Netflix / Playtone
# 265                                     Amazon Studios
# 266          Focus Features / FilmNation Entertainment
# 267                             Netflix / Bron Studios
#
#                                          Cast and crew   Ref.
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...    [2]
# 1    William Eubank (director); Brian Duffield, Ada...    [3]
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...    [4]
# 3    Jon Avnet (director/screenplay); Eric Nazarian...    NaN
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...    [5]
# ..                                                 ...    ...
# 263  Robert Rodriguez (director/screenplay); Priyan...  [236]
# 264  Paul Greengrass (director/screenplay); Luke Da...  [237]
# 265  Regina King (director); Kemp Powers (screenpla...  [238]
# 266  Emerald Fennell (director/screenplay); Carey M...  [239]
# 267  Kornél Mundruczó (director); Kata Wéber (scree...  [240]
#
# [268 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 263       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 264      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 265     One Night in Miami  Regina King (director); Kemp Powers (screenpla...
# 266  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 267      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [268 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'eee910e8cb81b6e613b9de55fd9c03c3'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 263       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 264      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 265     One Night in Miami  Regina King (director); Kemp Powers (screenpla...
# 266  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 267      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres
# 0                   Horror Mystery Thriller
# 1    Action Horror Science Fiction Thriller
# 2                                    Comedy
# 3                                     Drama
# 4                      Drama Thriller Crime
# ..                                      ...
# 263                   Action Fantasy Family
# 264                           Drama Western
# 265                                   Drama
# 266                    Thriller Crime Drama
# 267                                   Drama
#
# [268 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 263       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 264      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 265     One Night in Miami  Regina King (director); Kemp Powers (screenpla...
# 266  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 267      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                      genres     director_name  \
# 0                   Horror Mystery Thriller     Nicolas Pesce
# 1    Action Horror Science Fiction Thriller    William Eubank
# 2                                    Comedy     Miguel Arteta
# 3                                     Drama         Jon Avnet
# 4                      Drama Thriller Crime    Anthony Jerjen
# ..                                      ...               ...
# 263                   Action Fantasy Family  Robert Rodriguez
# 264                           Drama Western   Paul Greengrass
# 265                                   Drama       Regina King
# 266                    Thriller Crime Drama   Emerald Fennell
# 267                                   Drama  Kornél Mundruczó
#
#            actor_1_name       actor_2_name     actor_3_name
# 0    Andrea Riseborough      Demián Bichir         John Cho
# 1       Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2       Tiffany Haddish         Rose Byrne      Salma Hayek
# 3          Richard Gere     Peter Dinklage   Walton Goggins
# 4         Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                  ...                ...              ...
# 263     Priyanka Chopra       Pedro Pascal    YaYa Gosselin
# 264           Tom Hanks      Helena Zengel              NaN
# 265   Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 266      Carey Mulligan         Bo Burnham      Alison Brie
# 267       Vanessa Kirby       Shia LaBeouf     Molly Parker
#
# [268 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name        actor_1_name       actor_2_name     actor_3_name  \
# 0       Nicolas Pesce  Andrea Riseborough      Demián Bichir         John Cho
# 1      William Eubank     Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2       Miguel Arteta     Tiffany Haddish         Rose Byrne      Salma Hayek
# 3           Jon Avnet        Richard Gere     Peter Dinklage   Walton Goggins
# 4      Anthony Jerjen       Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                ...                 ...                ...              ...
# 263  Robert Rodriguez     Priyanka Chopra       Pedro Pascal    YaYa Gosselin
# 264   Paul Greengrass           Tom Hanks      Helena Zengel              NaN
# 265       Regina King   Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 266   Emerald Fennell      Carey Mulligan         Bo Burnham      Alison Brie
# 267  Kornél Mundruczó       Vanessa Kirby       Shia LaBeouf     Molly Parker
#
#                                      genres            movie_title
# 0                   Horror Mystery Thriller             The Grudge
# 1    Action Horror Science Fiction Thriller             Underwater
# 2                                    Comedy            Like a Boss
# 3                                     Drama          Three Christs
# 4                      Drama Thriller Crime      Inherit the Viper
# ..                                      ...                    ...
# 263                   Action Fantasy Family       We Can Be Heroes
# 264                           Drama Western      News of the World
# 265                                   Drama     One Night in Miami
# 266                    Thriller Crime Drama  Promising Young Woman
# 267                                   Drama      Pieces of a Woman
#
# [268 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      3
# actor_3_name     26
# genres            1
# movie_title       0
# comb             27
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# c:\users\ssc\anaconda3\envs\movies1\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df20
# Out:
#         director_name        actor_1_name       actor_2_name     actor_3_name  \
# 0       Nicolas Pesce  Andrea Riseborough      Demián Bichir         John Cho
# 1      William Eubank     Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2       Miguel Arteta     Tiffany Haddish         Rose Byrne      Salma Hayek
# 3           Jon Avnet        Richard Gere     Peter Dinklage   Walton Goggins
# 4      Anthony Jerjen       Josh Hartnett  Margarita Levieva   Chandler Riggs
# ..                ...                 ...                ...              ...
# 262       Pete Docter          Jamie Foxx           Tina Fey        Questlove
# 263  Robert Rodriguez     Priyanka Chopra       Pedro Pascal    YaYa Gosselin
# 265       Regina King   Kingsley Ben-Adir          Eli Goree      Aldis Hodge
# 266   Emerald Fennell      Carey Mulligan         Bo Burnham      Alison Brie
# 267  Kornél Mundruczó       Vanessa Kirby       Shia LaBeouf     Molly Parker
#
#                                               genres            movie_title  \
# 0                            Horror Mystery Thriller             the grudge
# 1             Action Horror Science Fiction Thriller             underwater
# 2                                             Comedy            like a boss
# 3                                              Drama          three christs
# 4                               Drama Thriller Crime      inherit the viper
# ..                                               ...                    ...
# 262  Animation Comedy Adventure Family Music Fantasy                   soul
# 263                            Action Fantasy Family       we can be heroes
# 265                                            Drama     one night in miami
# 266                             Thriller Crime Drama  promising young woman
# 267                                            Drama      pieces of a woman
#
#                                                   comb
# 0    Andrea Riseborough Demián Bichir John Cho Nico...
# 1    Kristen Stewart Vincent Cassel Jessica Henwick...
# 2    Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3    Richard Gere Peter Dinklage Walton Goggins Jon...
# 4    Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                                                 ...
# 262  Jamie Foxx Tina Fey Questlove Pete Docter Anim...
# 263  Priyanka Chopra Pedro Pascal YaYa Gosselin Rob...
# 265  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 266  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 267  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [241 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#               director_name       actor_1_name          actor_2_name  \
# 0             James Cameron        CCH Pounder      Joel David Moore
# 1            Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                Sam Mendes    Christoph Waltz          Rory Kinnear
# 3         Christopher Nolan          Tom Hardy        Christian Bale
# 4               Doug Walker        Doug Walker            Rob Walker
# ...                     ...                ...                   ...
# 5864           Greta Gerwig      Saoirse Ronan           Emma Watson
# 5865             Sam Mendes      George MacKay  Dean-Charles Chapman
# 5866  Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5867        Chinonye Chukwu      Alfre Woodard        Wendell Pierce
# 5868           Waymon Boone        Mena Suvari          Kevin Pollak
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5864         Florence Pugh                    Drama Romance
# 5865           Mark Strong                 War Drama Action
# 5866           Brie Larson                            Drama
# 5867           Aldis Hodge                            Drama
# 5868               unknown                  Horror Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5864                                       little women
# 5865                                               1917
# 5866                                         just mercy
# 5867                                           clemency
# 5868                                         apparition
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5864  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5865  George MacKay Dean-Charles Chapman Mark Strong...
# 5866  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5867  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 5868  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [5869 rows x 7 columns]

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#           director_name       actor_1_name      actor_2_name  \
# 0         James Cameron        CCH Pounder  Joel David Moore
# 1        Gore Verbinski        Johnny Depp     Orlando Bloom
# 2            Sam Mendes    Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan          Tom Hardy    Christian Bale
# 4           Doug Walker        Doug Walker        Rob Walker
# ...                 ...                ...               ...
# 6105        Pete Docter         Jamie Foxx          Tina Fey
# 6106   Robert Rodriguez    Priyanka Chopra      Pedro Pascal
# 6107        Regina King  Kingsley Ben-Adir         Eli Goree
# 6108    Emerald Fennell     Carey Mulligan        Bo Burnham
# 6109   Kornél Mundruczó      Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                                           genres  \
# 0                Wes Studi                  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                         Action Adventure Fantasy
# 2         Stephanie Sigman                        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                                  Action Thriller
# 4                  unknown                                      Documentary
# ...                    ...                                              ...
# 6105             Questlove  Animation Comedy Adventure Family Music Fantasy
# 6106         YaYa Gosselin                            Action Fantasy Family
# 6107           Aldis Hodge                                            Drama
# 6108           Alison Brie                             Thriller Crime Drama
# 6109          Molly Parker                                            Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6105                                               soul
# 6106                                   we can be heroes
# 6107                                 one night in miami
# 6108                              promising young woman
# 6109                                  pieces of a woman
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6105  Jamie Foxx Tina Fey Questlove Pete Docter Anim...
# 6106  Priyanka Chopra Pedro Pascal YaYa Gosselin Rob...
# 6107  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6108  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6109  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [6110 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
